# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# %cd '/content/drive/My Drive/project/polyppvt36'
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/project/polyppvt36
# davit.py   polyppvt36.ipynb  pvtv2.py	  Test.py   utils
# model_pth  pvt.py	     __pycache__  Train.py

# %%
# !pip install timm   
# !pip install thop
# !pip install mmcv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 22.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.4/605.4 KB 24.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 19.9 MB/s eta 0:00:00
# ...
#   Created wheel for mmcv: filename=mmcv-1.7.1-py2.py3-none-any.whl size=930736 sha256=582887aefe83a9e0ced691885446618dda146d220403c9dd215056354a408f68
#   Stored in directory: /root/.cache/pip/wheels/ae/69/b3/d097f4d265ae854179c4263f446283e3f402caa0dbf0083d05
# Successfully built mmcv
# ...

# %%
# !python Train.py --train_path ../dataset/TrainDataset/ --test_path ../dataset/TestDataset/
# Out:
# /usr/local/lib/python3.9/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.0001
# )
# False
# no augmentation
# ...

# %%
# !python Test.py
